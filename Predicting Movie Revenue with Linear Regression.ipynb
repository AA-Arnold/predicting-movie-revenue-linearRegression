# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('3.1 cost_revenue_clean.csv.csv')

# %%
def onePoint(x, power=0, const=0): 
    if power > 0 and const != 0:
        print('working')
        return
    if power > 0:
        print(x**power)
#     print(x)
    
onePoint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-4ae6693f21d8> in <module>
#       7 #     print(x)
#       8
# ----> 9 onePoint()
#
# TypeError: onePoint() missing 1 required positional argument: 'x'

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
4.250000e08
# Out:
# 425000000.0

# %%
2.783919e09
# Out:
# 2783919000.0

# %%
X = DataFrame(data, columns=['production_budget_usd'])
Y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, Y, alpha=0.3)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
regression = LinearRegression()
regression.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_ # theta_1
# Out:
# array([[3.11150918]])

# %%
# Intercept
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, Y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth=4)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
regression.score(X, Y)
# Out:
# 0.5496485356985727
